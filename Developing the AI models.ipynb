# %% [markdown]
# # Traditional Machine Learning Models using MFCC

# %% [markdown]
# ### Feature Extraction

# %%
import json
import os
import librosa
import numpy as np
from scipy.signal import butter, sosfilt
import sys

# Dataset Path
BASE_DATASET_PATH = "C:/Users/ndaru/OneDrive - KFUPM/THESIS/DATASET/MAN/ALL COMBINED V2"

# The extracted features are splitted into three JSON files: training, validation, testing
JSON_TRAIN_PATH = "train_MFCC_dur3.json"
JSON_VALIDATION_PATH = "validation_MFCC_dur3.json"
JSON_TEST_PATH = "test_MFCC_dur3.json"

# MFCC parameter
SAMPLE_RATE = 22050
TRACK_DURATION = 3  # in seconds
SAMPLES_PER_TRACK = int(SAMPLE_RATE * TRACK_DURATION)

# Creating a function for filtering 250-2000 Hz
def bandpass_filter(signal, sr, lowcut=250, highcut=2000, order=5):

    sos = butter(order, [lowcut, highcut], btype='band', fs=sr, output='sos')
    return sosfilt(sos, signal)

# Creating a function for extracting MFCC from datasets
def process_files(base_path, split_name, num_mfcc=32, n_fft=2048, hop_length=128):

    mapping = []
    labels = []
    mfcc_left_list = []
    mfcc_right_list = []
    
    class_dirs = sorted([d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))])
    
    for i, class_dir in enumerate(class_dirs):
        semantic_label = class_dir
        if split_name == "training":
            mapping.append(semantic_label)
        print(f"\nProcessing: {semantic_label} -> {split_name}")
        
        dirpath = os.path.join(base_path, class_dir, split_name)

        if not os.path.isdir(dirpath):
            print(f"Directory not found, skipping: {dirpath}")
            continue
            
        filenames = [f for f in os.listdir(dirpath) if f.lower().endswith(('.wav', '.mp3', '.flac'))]

        for f in filenames:
            file_path = os.path.join(dirpath, f)
            try:
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE, mono=False)

                if signal.shape[0] != 2:
                    print(f"Skipping non-stereo file: {file_path}")
                    continue

                # Adding paddings for datasets that are below 3 seconds
                if signal.shape[1] < SAMPLES_PER_TRACK:
                    pad_length = SAMPLES_PER_TRACK - signal.shape[1]
                    signal = np.pad(signal, ((0, 0), (0, pad_length)), mode="constant")
                elif signal.shape[1] > SAMPLES_PER_TRACK:
                    signal = signal[:, :SAMPLES_PER_TRACK]

                left_channel = bandpass_filter(signal[0], sample_rate)
                right_channel = bandpass_filter(signal[1], sample_rate)

                mfcc_left = librosa.feature.mfcc(y=left_channel, sr=sample_rate,
                                                 n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length).T
                mfcc_right = librosa.feature.mfcc(y=right_channel, sr=sample_rate,
                                                  n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length).T
                
                mfcc_left_list.append(mfcc_left)
                mfcc_right_list.append(mfcc_right)
                labels.append(i)
                print(f"Loaded file: {file_path}")

            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    if not mapping:
        mapping = class_dirs

    return mapping, labels, mfcc_left_list, mfcc_right_list

# Creating a function for normalizing training datasets
def save_normalized_data(json_path, mapping, labels, mfcc_left_list, mfcc_right_list, mean_l, std_l, mean_r, std_r):
    
    data = {"mapping": mapping, "labels": labels, "mfcc_left": [], "mfcc_right": []}
    
    for mfcc_l, mfcc_r in zip(mfcc_left_list, mfcc_right_list):
        norm_mfcc_l = (mfcc_l - mean_l) / (std_l + 1e-10)
        norm_mfcc_r = (mfcc_r - mean_r) / (std_r + 1e-10)
        
        data["mfcc_left"].append(norm_mfcc_l.tolist())
        data["mfcc_right"].append(norm_mfcc_r.tolist())
        
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
    print(f"\nDatasets are successfully saved in {json_path}")

# Running all functions that have made
if __name__ == "__main__":
    print("="*30)
    print("PROCESSING THE TRAINING DATASET")
    print("="*30)
    train_mapping, train_labels, train_mfcc_l, train_mfcc_r = process_files(BASE_DATASET_PATH, "training")

    if not train_mfcc_l:
        print("\n\nERROR: No training dataset has been successfully uploaded.")
        sys.exit()

    print("\nCalculating normalization")
    stacked_left = np.vstack(train_mfcc_l)
    mean_left = np.mean(stacked_left, axis=0)
    std_left = np.std(stacked_left, axis=0)

    stacked_right = np.vstack(train_mfcc_r)
    mean_right = np.mean(stacked_right, axis=0)
    std_right = np.std(stacked_right, axis=0)
    print("Normalization has been successfully calculated.")

    save_normalized_data(JSON_TRAIN_PATH, train_mapping, train_labels, train_mfcc_l, train_mfcc_r,
                         mean_left, std_left, mean_right, std_right)
                         
    print("\n" + "="*30)
    print("PROCESSING THE VALIDATION DATASET")
    print("="*30)
    _, val_labels, val_mfcc_l, val_mfcc_r = process_files(BASE_DATASET_PATH, "validation")
    save_normalized_data(JSON_VALIDATION_PATH, train_mapping, val_labels, val_mfcc_l, val_mfcc_r,
                         mean_left, std_left, mean_right, std_right)

    print("\n" + "="*30)
    print("PROCESSING THE TESTING DATASET")
    print("="*30)
    _, test_labels, test_mfcc_l, test_mfcc_r = process_files(BASE_DATASET_PATH, "testing")
    save_normalized_data(JSON_TEST_PATH, train_mapping, test_labels, test_mfcc_l, test_mfcc_r,
                         mean_left, std_left, mean_right, std_right)

# %% [markdown]
# ### Model Development

# %%
import os
import json
import numpy as np
import pandas as pd
from pycaret.classification import *

# Defining the JSON files
BASE_PATH = 'C:/Users/ndaru/OneDrive - KFUPM/THESIS/DATASET'
JSON_TRAIN_PATH = os.path.join(BASE_PATH, 'train_MFCC_dur3.json')
JSON_VALIDATION_PATH = os.path.join(BASE_PATH, 'validation_MFCC_dur3.json')
JSON_TEST_PATH = os.path.join(BASE_PATH, 'test_MFCC_dur3.json')

# Creating a function for loading and creating dataframe
def load_and_create_dataframe(json_path):
   
    print(f"Processing file: {json_path}...")
    
    if not os.path.exists(json_path):
        print(f"ERROR: File is not found in '{json_path}'.")
        return None

    with open(json_path, 'r') as f:
        data = json.load(f)

    mapping = data['mapping']
    labels = data['labels']
    mfcc_left_data = data['mfcc_left']
    mfcc_right_data = data['mfcc_right']

    records = []
    for i in range(len(labels)):
        label_name = mapping[labels[i]]
        mfcc_left = np.array(mfcc_left_data[i]).flatten()
        mfcc_right = np.array(mfcc_right_data[i]).flatten()
        features = np.concatenate([mfcc_left, mfcc_right])
        row = {'label': label_name}
        row.update({f'feat_{j}': val for j, val in enumerate(features)})
        records.append(row)

    df = pd.DataFrame(records)
    print(f"✅ Finish. Dataframe Dimension: {df.shape}")
    return df


if __name__ == "__main__":
    
    train_df = load_and_create_dataframe(JSON_TRAIN_PATH)
    validation_df = load_and_create_dataframe(JSON_VALIDATION_PATH)
    test_df = load_and_create_dataframe(JSON_TEST_PATH)

    if train_df is None or validation_df is None or test_df is None:
        print("\nThe process is stopped as the data can be identified")
    else:
        combined_train_df = pd.concat([train_df, validation_df], ignore_index=True)

        print(f"Dataframe Dimension for Training Dataset: {combined_train_df.shape}")
        print(f"Dataframe Dimension for Testing Dataset: {test_df.shape}")

        print("\nLaunching PyCaret...")
        clf_setup = setup(
            data=combined_train_df, 
            test_data=test_df, 
            target='label', 
            session_id=123,
            index=False, 
            verbose=True
        )

        print("\nComparing the models...")
        best_model = compare_models()
        print("\nThe best model has found:")
        print(best_model)

        # Save the model
        model_filename = 'MFCC Trad Models'
        save_model(best_model, model_filename)

# %% [markdown]
# # Traditional Machine Learning Models using SVD-based Spectrogram

# %% [markdown]
# ### Feature Extraction

# %%
import json
import os
import librosa
import numpy as np
from scipy.signal import butter, sosfilt
import sys

# Dataset Path
BASE_DATASET_PATH = "C:/Users/ndaru/OneDrive - KFUPM/THESIS/DATASET/MAN/ALL COMBINED V2"

# The extracted features are splitted into three JSON files: training, validation, testing
JSON_TRAIN_PATH = "train_SVD_dur.json"
JSON_VALIDATION_PATH = "validation_SVD_dur.json"
JSON_TEST_PATH = "test_SVD_dur.json"


# Defining Parameters
SAMPLE_RATE = 22050
TRACK_DURATION = 3  # in seconds
SAMPLES_PER_TRACK = int(SAMPLE_RATE * TRACK_DURATION)
HOP_LENGTH = 128
N_FFT = 2048
SVD_K = 32

# Creating a function for filtering 250-2000 Hz
def bandpass_filter(signal, sr, lowcut=250, highcut=2000, order=5):
   
    sos = butter(order, [lowcut, highcut], btype='band', fs=sr, output='sos')
    return sosfilt(sos, signal)

# Creating a function for extracting Spectrogram from datasets
def process_files(base_path, split_name, num_mfcc=32, n_fft=2048, hop_length=128):
   
    mapping = []
    labels = []
    log_specs_left = []
    log_specs_right = []
    
    class_dirs = sorted([d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))])
    
    for i, class_dir in enumerate(class_dirs):
        semantic_label = class_dir
        if split_name == "training":
            mapping.append(semantic_label)
        print(f"\nProcessing: {semantic_label} -> {split_name}")
        
        dirpath = os.path.join(base_path, class_dir, split_name)

        if not os.path.isdir(dirpath):
            print(f"Directory not found, skipping: {dirpath}")
            continue
            
        filenames = [f for f in os.listdir(dirpath) if f.lower().endswith(('.wav', '.mp3', '.flac'))]

        for f in filenames:
            file_path = os.path.join(dirpath, f)
            try:
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE, mono=False)

                if signal.shape[0] != 2:
                    print(f"Skipping non-stereo file: {file_path}")
                    continue

                # Adding paddings for datasets that are below 3 seconds
                if signal.shape[1] < SAMPLES_PER_TRACK:
                    pad_length = SAMPLES_PER_TRACK - signal.shape[1]
                    signal = np.pad(signal, ((0, 0), (0, pad_length)), mode="constant")
                elif signal.shape[1] > SAMPLES_PER_TRACK:
                    signal = signal[:, :SAMPLES_PER_TRACK]

                left_channel = bandpass_filter(signal[0], sample_rate)
                right_channel = bandpass_filter(signal[1], sample_rate)

                stft_left = librosa.stft(y=left_channel, n_fft=N_FFT, hop_length=HOP_LENGTH)
                stft_right = librosa.stft(y=right_channel, n_fft=N_FFT, hop_length=HOP_LENGTH)
    
                mag_left = np.abs(stft_left)
                mag_right = np.abs(stft_right)
    
                log_spec_left = librosa.amplitude_to_db(mag_left)
                log_spec_right = librosa.amplitude_to_db(mag_right)
    
                log_specs_left.append(log_spec_left)
                log_specs_right.append(log_spec_right)

                labels.append(i)
                print(f"Loaded file: {file_path}")

            except Exception as e:
                print(f"Error processing {file_path}: {e}")

    if not mapping:
        mapping = class_dirs

    return mapping, labels, log_specs_left, log_specs_right

# Creating a function for normalizing training datasets and applying SVD
def save_normalized_data(json_path, mapping, labels, log_specs_left, log_specs_right, mean_l, std_l, mean_r, std_r):
    
    data = {"mapping": mapping, "labels": labels, "log_left": [], "log_right": []}
    
    for svd_l, svd_r in zip(log_specs_left, log_specs_right):
        norm_svd_l = (svd_l - mean_l) / (std_l + 1e-10)
        norm_svd_r = (svd_r - mean_r) / (std_r + 1e-10)

        _, _, Vt_left = np.linalg.svd(norm_svd_l, full_matrices=False)
        _, _, Vt_right = np.linalg.svd(norm_svd_r, full_matrices=False)
    
        vt_left_flat = Vt_left[:SVD_K].flatten()
        vt_right_flat = Vt_right[:SVD_K].flatten()
        
        data["log_left"].append(vt_left_flat.tolist())
        data["log_right"].append(vt_right_flat.tolist())
        
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)
    print(f"\nDatasets are successfully saved in {json_path}")


if __name__ == "__main__":
    print("="*30)
    print("PROCESSING THE TRAINING DATASET")
    print("="*30)
    train_mapping, train_labels, train_mfcc_l, train_mfcc_r = process_files(BASE_DATASET_PATH, "training")

    if not train_mfcc_l:
        print("\n\nERROR: No training dataset has been successfully uploaded.")
        sys.exit()

    print("\nCalculating normalization...")
    stacked_left = np.vstack(train_mfcc_l)
    mean_left = np.mean(stacked_left, axis=0)
    std_left = np.std(stacked_left, axis=0)

    stacked_right = np.vstack(train_mfcc_r)
    mean_right = np.mean(stacked_right, axis=0)
    std_right = np.std(stacked_right, axis=0)
    print("Normalization has been successfully calculated.")

    save_normalized_data(JSON_TRAIN_PATH, train_mapping, train_labels, train_mfcc_l, train_mfcc_r,
                         mean_left, std_left, mean_right, std_right)
                         
    print("\n" + "="*30)
    print("PROCESSING THE VALIDATION DATASET")
    print("="*30)
    _, val_labels, val_mfcc_l, val_mfcc_r = process_files(BASE_DATASET_PATH, "validation")
    save_normalized_data(JSON_VALIDATION_PATH, train_mapping, val_labels, val_mfcc_l, val_mfcc_r,
                         mean_left, std_left, mean_right, std_right)

    print("\n" + "="*30)
    print("PROCESSING THE TESTING DATASET")
    print("="*30)
    _, test_labels, test_mfcc_l, test_mfcc_r = process_files(BASE_DATASET_PATH, "testing")
    save_normalized_data(JSON_TEST_PATH, train_mapping, test_labels, test_mfcc_l, test_mfcc_r,
                         mean_left, std_left, mean_right, std_right)

# %% [markdown]
# ### Model Development

# %%
import os
import json
import numpy as np
import pandas as pd
from pycaret.classification import *

# Defining the JSON files
BASE_PATH = 'C:/Users/ndaru/OneDrive - KFUPM/THESIS/DATASET'
JSON_TRAIN_PATH = os.path.join(BASE_PATH, 'train_SVD_dur3.json')
JSON_VALIDATION_PATH = os.path.join(BASE_PATH, 'validation_SVD_dur3.json')
JSON_TEST_PATH = os.path.join(BASE_PATH, 'test_SVD_dur3.json')

# Creating a function for loading and creating dataframe
def load_and_create_dataframe(json_path):
   
    print(f"Processing file: {json_path}...")
    
    if not os.path.exists(json_path):
        print(f"ERROR: File is not found in '{json_path}'.")
        return None

    with open(json_path, 'r') as f:
        data = json.load(f)

    mapping = data['mapping']
    labels = data['labels']
    svd_left_data = data['log_left']
    svd_right_data = data['log_right']

    records = []
    for i in range(len(labels)):
        label_name = mapping[labels[i]]
        svd_left = np.array(svd_left_data[i]).flatten()
        svd_right = np.array(svd_right_data[i]).flatten()
        features = np.concatenate([svd_left, svd_right])
        row = {'label': label_name}
        row.update({f'feat_{j}': val for j, val in enumerate(features)})
        records.append(row)

    df = pd.DataFrame(records)
    print(f"✅ Finish. Dataframe Dimension: {df.shape}")
    return df


if __name__ == "__main__":
    
    train_df = load_and_create_dataframe(JSON_TRAIN_PATH)
    validation_df = load_and_create_dataframe(JSON_VALIDATION_PATH)
    test_df = load_and_create_dataframe(JSON_TEST_PATH)

    if train_df is None or validation_df is None or test_df is None:
        print("\nThe process is stopped as the data can be identified")
    else:
        combined_train_df = pd.concat([train_df, validation_df], ignore_index=True)

        print(f"Dataframe Dimension for Training Dataset: {combined_train_df.shape}")
        print(f"Dataframe Dimension for Testing Dataset: {test_df.shape}")

        print("\nLaunching PyCaret...")
        clf_setup = setup(
            data=combined_train_df, 
            test_data=test_df, 
            target='label', 
            session_id=123,
            index=False, 
            verbose=True
        )

        print("\nComparing the models...")
        best_model = compare_models()
        print("\nThe best model has found:")
        print(best_model)

        # Save the model
        model_filename = 'SVD Trad Models'
        save_model(best_model, model_filename)

# %% [markdown]
# # CNN using MFCC & Bi-LSTM

# %% [markdown]
# ### Feature Extraction

# %%
import json
import os
import librosa
import numpy as np
from scipy.signal import butter, sosfilt
import sys

# Dataset path
BASE_DATASET_PATH = r"C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\MAN\ALL COMBINED V2"

# The extracted features are splitted into three JSON files: training, validation, testing
TRAIN_JSON_PATH = "train_MFCC_CNN_dur3.json"
VALIDATION_JSON_PATH = "validation_MFCC_CNN_dur3.json"
TEST_JSON_PATH = "test_MFCC_CNN_dur3.json"

# Defining Parameters
SAMPLE_RATE = 22050
TRACK_DURATION = 3  # in seconds
SAMPLES_PER_TRACK = int(SAMPLE_RATE * TRACK_DURATION)
NUM_MFCC = 32
N_FFT = 2048
HOP_LENGTH = 128

# Creating a function for filtering 250-2000 Hz
def bandpass_filter(signal, sr, lowcut=250, highcut=2000, order=5):
    
    sos = butter(order, [lowcut, highcut], btype='band', fs=sr, output='sos')
    return sosfilt(sos, signal)

# Creating a function for extracting MFCC from datasets
def process_data(base_path, class_mappings, splits_to_process):

    all_data = {split: {"labels": [], "mfcc_left": [], "mfcc_right": []} for split in splits_to_process}

    for label_index, class_name in enumerate(class_mappings):
        print(f"\nProcessing Class: {class_name} (Label: {label_index})")
        
        for split_name in splits_to_process:
            split_path = os.path.join(base_path, class_name, split_name)
            
            if not os.path.isdir(split_path):
                print(f"  -> Directory is not found, pass: {split_path}")
                continue
            
            print(f"  -> Split Processing: {split_name}")

            for f in sorted(os.listdir(split_path)):
                if not f.lower().endswith(('.wav', '.mp3', '.flac')):
                    continue
                    
                file_path = os.path.join(split_path, f)
                
                try:
                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE, mono=False)

                    if signal.shape[0] != 2:
                        print(f"     -> Passing non-stereo file: {f}")
                        continue

                    # Adding paddings for datasets that are below 3 seconds
                    if signal.shape[1] < SAMPLES_PER_TRACK:
                        pad_length = SAMPLES_PER_TRACK - signal.shape[1]
                        signal = np.pad(signal, ((0, 0), (0, pad_length)), mode="constant")
                    elif signal.shape[1] > SAMPLES_PER_TRACK:
                        signal = signal[:, :SAMPLES_PER_TRACK]

                    left_channel = bandpass_filter(signal[0], sample_rate)
                    right_channel = bandpass_filter(signal[1], sample_rate)

                    mfcc_left = librosa.feature.mfcc(y=left_channel, sr=sample_rate, n_mfcc=NUM_MFCC, n_fft=N_FFT, hop_length=HOP_LENGTH).T
                    mfcc_right = librosa.feature.mfcc(y=right_channel, sr=sample_rate, n_mfcc=NUM_MFCC, n_fft=N_FFT, hop_length=HOP_LENGTH).T

                    all_data[split_name]["mfcc_left"].append(mfcc_left)
                    all_data[split_name]["mfcc_right"].append(mfcc_right)
                    all_data[split_name]["labels"].append(label_index)

                except Exception as e:
                    print(f"     -> Failed to load file {f}. Error: {e}")

    return all_data

# Creating a fucntion for saving the JSON file
def save_to_json(data, json_path, class_mappings):
    data_to_save = {
        "mapping": class_mappings,
        "labels": data["labels"],
        "mfcc_left": [mfcc.tolist() for mfcc in data["mfcc_left"]],
        "mfcc_right": [mfcc.tolist() for mfcc in data["mfcc_right"]]
    }
    with open(json_path, "w") as fp:
        json.dump(data_to_save, fp, indent=4)
    print(f"\nData has been saved in {json_path}")

if __name__ == "__main__":
    try:
        class_mappings = sorted([d for d in os.listdir(BASE_DATASET_PATH) if os.path.isdir(os.path.join(BASE_DATASET_PATH, d))])
        if not class_mappings:
            raise FileNotFoundError
    except FileNotFoundError:
        print(f"❌ ERROR: No folder class found in: {BASE_DATASET_PATH}")
        print("Ensure the path contains folder 'High Intelligibility' dan 'Low Intelligibility'.")
        sys.exit()

    print(f"Class detected: {class_mappings}")

    splits = ["training", "validation", "testing"]
    processed_data = process_data(BASE_DATASET_PATH, class_mappings, splits)

    train_data = processed_data["training"]
    validation_data = processed_data["validation"]
    test_data = processed_data["testing"]

    # Calculating normalization..
    all_train_mfcc_left = np.vstack(train_data["mfcc_left"])
    all_train_mfcc_right = np.vstack(train_data["mfcc_right"])
    
    mean_left = np.mean(all_train_mfcc_left, axis=0)
    std_left = np.std(all_train_mfcc_left, axis=0)
    mean_right = np.mean(all_train_mfcc_right, axis=0)
    std_right = np.std(all_train_mfcc_right, axis=0)

    epsilon = 1e-10
    for split_name in splits:
        current_data = processed_data[split_name]
        current_data["mfcc_left"] = [(mfcc - mean_left) / (std_left + epsilon) for mfcc in current_data["mfcc_left"]]
        current_data["mfcc_right"] = [(mfcc - mean_right) / (std_right + epsilon) for mfcc in current_data["mfcc_right"]]
    
    print("\nNormalization for training dataset has been successfullt calculated.")

    # Saving the JSON file
    save_to_json(train_data, TRAIN_JSON_PATH, class_mappings)
    save_to_json(validation_data, VALIDATION_JSON_PATH, class_mappings)
    save_to_json(test_data, TEST_JSON_PATH, class_mappings)
    
    print("\n✅ Process is over.")

# %% [markdown]
# ### Model Development (CNN using MFCC)

# %%
import json
import os
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Importing the JSON files
BASE_PATH = r"C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET"
TRAIN_JSON_PATH = os.path.join(BASE_PATH, "train_MFCC_CNN_dur3.json")
VALIDATION_JSON_PATH = os.path.join(BASE_PATH, "validation_MFCC_CNN_dur3.json")
TEST_JSON_PATH = os.path.join(BASE_PATH, "test_MFCC_CNN_dur3.json")

# Creating a dunction for loadind dataset
def load_data_from_file(data_path):
   
    print(f"Uploading data from: {data_path}")
    with open(data_path, "r") as fp:
        data = json.load(fp)

    mfcc_left = np.array(data["mfcc_left"])
    mfcc_right = np.array(data["mfcc_right"])
    y = np.array(data["labels"])
    
    mask = (y == 2) | (y == 3)
    
    X_unfiltered = np.stack((mfcc_left, mfcc_right), axis=-1)
    
    X_filtered = X_unfiltered[mask]
    y_filtered = y[mask]

    y_remapped = y_filtered.copy()
    y_remapped[y_filtered == 2] = 0
    y_remapped[y_filtered == 3] = 1

    X = X_filtered[..., np.newaxis]
    y = y_remapped

    print(f"  -> Shape X: {X.shape}, Shape Y: {y.shape}")
    print(f"  -> Label: {np.unique(y)}")
    return X, y

# Creating a plot for ploting accuracy and loss
def plot_history(history, validation_freq=1):
    
    import numpy as np

    train_acc  = np.array(history.history["accuracy"])
    train_loss = np.array(history.history["loss"])
    val_acc    = np.array(history.history.get("val_accuracy", []))
    val_loss   = np.array(history.history.get("val_loss", []))

    epochs = np.arange(1, len(train_acc) + 1)

    if validation_freq > 1 and len(val_acc) > 0:
        val_epochs = np.arange(validation_freq, len(train_acc) + 1, validation_freq)
        train_acc  = train_acc[val_epochs - 1]
        train_loss = train_loss[val_epochs - 1]
        epochs     = val_epochs

    fig, axs = plt.subplots(2, figsize=(10, 8))

    axs[0].plot(epochs, train_acc, label="Training Accuracy")
    if len(val_acc):
        axs[0].plot(epochs, val_acc, label="Validation Accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")

    axs[1].plot(epochs, train_loss, label="Training Loss")
    if len(val_loss):
        axs[1].plot(epochs, val_loss, label="Validation Loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")

    plt.tight_layout()
    plt.show()

# Creating a function for building model
def build_model(input_shape):

    model = Sequential()
    
    model.add(Conv3D(filters=16, kernel_size=(5, 3, 2), activation='relu', input_shape=input_shape, padding='same'))
    model.add(BatchNormalization())
    model.add(SpatialDropout3D(0.3))
    model.add(MaxPooling3D(pool_size=(3, 3, 2)))
    
    model.add(Conv3D(filters=32, kernel_size=(5, 3, 1), activation='relu', kernel_regularizer=keras.regularizers.l2(0.001), padding='same'))
    model.add(BatchNormalization())
    model.add(SpatialDropout3D(0.3))
    model.add(MaxPooling3D(pool_size=(3, 3, 1)))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(2, activation='softmax'))

    return model


if __name__ == "__main__":

    X_train, y_train = load_data_from_file(TRAIN_JSON_PATH)
    X_validation, y_validation = load_data_from_file(VALIDATION_JSON_PATH)
    X_test, y_test = load_data_from_file(TEST_JSON_PATH)

    input_shape = X_train.shape[1:]
    model = build_model(input_shape)

    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
    
    # Tambahkan ini sebelum training
    checkpoint_path = "CNN_MFCC_best_model.weights.h5"
    model_checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )
    
    # EarlyStopping berdasarkan akurasi validasi, bukan loss
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=5,  # berhenti jika val_accuracy stagnan/turun 5 kali berturut-turut
        restore_best_weights=True,
        mode='max',
        verbose=1
    )
    
    # Learning rate scheduler tetap
    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        mode='max',
        verbose=1
    )
    
    # Mulai training dengan validasi setiap 4 epoch
    history = model.fit(
        X_train, y_train,
        validation_data=(X_validation, y_validation),
        batch_size=8,
        epochs=100,
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1,
        validation_freq=4  # validasi setiap 4 epoch
    )

    model.load_weights(checkpoint_path)
    plot_history(history, validation_freq=4)

    print("\n--- Evaluating Model ---")
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print(f'\nAccuracy: {test_acc:.4f}')
    print(f'Loss: {test_loss:.4f}')

    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs[:, 1] > 0.5).astype(int) 
    
    # Calculating confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    labels = np.unique(y_test)
    
    # Visualizing the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()
# Out:
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\train_MFCC_CNN_dur3.json
#   -> Shape X: (220, 517, 32, 2, 1), Shape Y: (220,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\validation_MFCC_CNN_dur3.json
#   -> Shape X: (94, 517, 32, 2, 1), Shape Y: (94,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\test_MFCC_CNN_dur3.json
#   -> Shape X: (56, 517, 32, 2, 1), Shape Y: (56,)
#   -> Label: [0 1]
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_27"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d_31 (Conv3D)                   │ (None, 517, 32, 2, 16)      │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_31               │ (None, 517, 32, 2, 16)      │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout3d_30                 │ (None, 517, 32, 2, 16)      │               0 │
# │ (SpatialDropout3D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_30 (MaxPooling3D)      │ (None, 172, 10, 1, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_32 (Conv3D)                   │ (None, 172, 10, 1, 32)      │           7,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_32               │ (None, 172, 10, 1, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout3d_31                 │ (None, 172, 10, 1, 32)      │               0 │
# │ (SpatialDropout3D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_31 (MaxPooling3D)      │ (None, 57, 3, 1, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_15 (Flatten)                 │ (None, 5472)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_46 (Dense)                     │ (None, 128)                 │         700,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_31 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_47 (Dense)                     │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 709,202 (2.71 MB)
#  Trainable params: 709,106 (2.71 MB)
#  Non-trainable params: 96 (384.00 B)
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 149ms/step - accuracy: 0.4979 - loss: 1.6048 - learning_rate: 1.0000e-04
# Epoch 2/100
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\model_checkpoint.py:302: UserWarning: Can save best model only with val_accuracy available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.6300 - loss: 0.8247 - learning_rate: 1.0000e-04
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.5511 - loss: 0.9261 - learning_rate: 1.0000e-04
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.6520 - loss: 0.7259
# Epoch 4: val_accuracy improved from -inf to 0.54255, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 199ms/step - accuracy: 0.6523 - loss: 0.7258 - val_accuracy: 0.5426 - val_loss: 0.6786 - learning_rate: 1.0000e-04
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.6098 - loss: 0.7731 - learning_rate: 1.0000e-04
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - accuracy: 0.7074 - loss: 0.5859 - learning_rate: 1.0000e-04
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.6579 - loss: 0.6775 - learning_rate: 1.0000e-04
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7232 - loss: 0.6317
# Epoch 8: val_accuracy improved from 0.54255 to 0.67021, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.7227 - loss: 0.6308 - val_accuracy: 0.6702 - val_loss: 0.6244 - learning_rate: 1.0000e-04
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.7257 - loss: 0.5443 - learning_rate: 1.0000e-04
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.7913 - loss: 0.5260 - learning_rate: 1.0000e-04
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.7293 - loss: 0.6141 - learning_rate: 1.0000e-04
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7420 - loss: 0.5412
# Epoch 12: val_accuracy improved from 0.67021 to 0.74468, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.7426 - loss: 0.5404 - val_accuracy: 0.7447 - val_loss: 0.5331 - learning_rate: 1.0000e-04
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.7322 - loss: 0.5128 - learning_rate: 1.0000e-04
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.7799 - loss: 0.4979 - learning_rate: 1.0000e-04
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.7517 - loss: 0.5182 - learning_rate: 1.0000e-04
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8840 - loss: 0.3585
# Epoch 16: val_accuracy improved from 0.74468 to 0.78723, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.8829 - loss: 0.3601 - val_accuracy: 0.7872 - val_loss: 0.4710 - learning_rate: 1.0000e-04
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.8375 - loss: 0.3783 - learning_rate: 1.0000e-04
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.8322 - loss: 0.4064 - learning_rate: 1.0000e-04
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - accuracy: 0.8333 - loss: 0.3552 - learning_rate: 1.0000e-04
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8302 - loss: 0.3595
# Epoch 20: val_accuracy improved from 0.78723 to 0.80851, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.8296 - loss: 0.3606 - val_accuracy: 0.8085 - val_loss: 0.4225 - learning_rate: 1.0000e-04
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.8336 - loss: 0.4350 - learning_rate: 1.0000e-04
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8669 - loss: 0.3263 - learning_rate: 1.0000e-04
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.8104 - loss: 0.3800 - learning_rate: 1.0000e-04
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8617 - loss: 0.3169
# Epoch 24: val_accuracy improved from 0.80851 to 0.82979, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.8604 - loss: 0.3196 - val_accuracy: 0.8298 - val_loss: 0.3899 - learning_rate: 1.0000e-04
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8419 - loss: 0.3774 - learning_rate: 1.0000e-04
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.9176 - loss: 0.2224 - learning_rate: 1.0000e-04
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8644 - loss: 0.3065 - learning_rate: 1.0000e-04
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8999 - loss: 0.2515
# Epoch 28: val_accuracy did not improve from 0.82979
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 191ms/step - accuracy: 0.8993 - loss: 0.2519 - val_accuracy: 0.8298 - val_loss: 0.3604 - learning_rate: 1.0000e-04
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.8832 - loss: 0.3552 - learning_rate: 1.0000e-04
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.8920 - loss: 0.2654 - learning_rate: 1.0000e-04
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 150ms/step - accuracy: 0.9117 - loss: 0.2297 - learning_rate: 1.0000e-04
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9371 - loss: 0.1846
# Epoch 32: val_accuracy improved from 0.82979 to 0.84043, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.9366 - loss: 0.1858 - val_accuracy: 0.8404 - val_loss: 0.3623 - learning_rate: 1.0000e-04
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 193ms/step - accuracy: 0.9349 - loss: 0.2079 - learning_rate: 1.0000e-04
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.9566 - loss: 0.1512 - learning_rate: 1.0000e-04
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.9421 - loss: 0.1794 - learning_rate: 1.0000e-04
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9096 - loss: 0.2356
# Epoch 36: val_accuracy improved from 0.84043 to 0.85106, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 11s 215ms/step - accuracy: 0.9097 - loss: 0.2352 - val_accuracy: 0.8511 - val_loss: 0.3500 - learning_rate: 1.0000e-04
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.9328 - loss: 0.1872 - learning_rate: 1.0000e-04
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9171 - loss: 0.2361 - learning_rate: 1.0000e-04
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.9548 - loss: 0.1778 - learning_rate: 1.0000e-04
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9632 - loss: 0.1306
# Epoch 40: val_accuracy did not improve from 0.85106
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 219ms/step - accuracy: 0.9626 - loss: 0.1317 - val_accuracy: 0.8404 - val_loss: 0.3056 - learning_rate: 1.0000e-04
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 164ms/step - accuracy: 0.9818 - loss: 0.0975 - learning_rate: 1.0000e-04
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.9557 - loss: 0.1260 - learning_rate: 1.0000e-04
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.9579 - loss: 0.1613 - learning_rate: 1.0000e-04
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9393 - loss: 0.1872
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 44: val_accuracy did not improve from 0.85106
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.9397 - loss: 0.1867 - val_accuracy: 0.8511 - val_loss: 0.3123 - learning_rate: 1.0000e-04
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9494 - loss: 0.1672 - learning_rate: 5.0000e-05
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9541 - loss: 0.1342 - learning_rate: 5.0000e-05
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9687 - loss: 0.1038 - learning_rate: 5.0000e-05
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9561 - loss: 0.1382
# Epoch 48: val_accuracy improved from 0.85106 to 0.86170, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - accuracy: 0.9560 - loss: 0.1387 - val_accuracy: 0.8617 - val_loss: 0.3395 - learning_rate: 5.0000e-05
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.9885 - loss: 0.0754 - learning_rate: 5.0000e-05
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.9793 - loss: 0.0947 - learning_rate: 5.0000e-05
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9811 - loss: 0.0728 - learning_rate: 5.0000e-05
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9657 - loss: 0.1110
# Epoch 52: val_accuracy did not improve from 0.86170
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.9663 - loss: 0.1108 - val_accuracy: 0.8617 - val_loss: 0.3110 - learning_rate: 5.0000e-05
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9647 - loss: 0.1465 - learning_rate: 5.0000e-05
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9784 - loss: 0.0967 - learning_rate: 5.0000e-05
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9877 - loss: 0.0730 - learning_rate: 5.0000e-05
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9592 - loss: 0.1114
# Epoch 56: val_accuracy improved from 0.86170 to 0.87234, saving model to CNN_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.9598 - loss: 0.1108 - val_accuracy: 0.8723 - val_loss: 0.3306 - learning_rate: 5.0000e-05
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9589 - loss: 0.1082 - learning_rate: 5.0000e-05
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9967 - loss: 0.0798 - learning_rate: 5.0000e-05
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.9800 - loss: 0.0835 - learning_rate: 5.0000e-05
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9544 - loss: 0.1721
# Epoch 60: val_accuracy did not improve from 0.87234
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - accuracy: 0.9547 - loss: 0.1707 - val_accuracy: 0.8617 - val_loss: 0.3278 - learning_rate: 5.0000e-05
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9432 - loss: 0.1302 - learning_rate: 5.0000e-05
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.9849 - loss: 0.0847 - learning_rate: 5.0000e-05
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9865 - loss: 0.0837 - learning_rate: 5.0000e-05
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9993 - loss: 0.0512
# Epoch 64: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 64: val_accuracy did not improve from 0.87234
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.9990 - loss: 0.0519 - val_accuracy: 0.8511 - val_loss: 0.3428 - learning_rate: 5.0000e-05
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.9856 - loss: 0.0703 - learning_rate: 2.5000e-05
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.9815 - loss: 0.0856 - learning_rate: 2.5000e-05
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 146ms/step - accuracy: 0.9841 - loss: 0.0760 - learning_rate: 2.5000e-05
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9532 - loss: 0.1248
# Epoch 68: val_accuracy did not improve from 0.87234
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - accuracy: 0.9537 - loss: 0.1236 - val_accuracy: 0.8511 - val_loss: 0.3280 - learning_rate: 2.5000e-05
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 142ms/step - accuracy: 0.9931 - loss: 0.0734 - learning_rate: 2.5000e-05
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - accuracy: 0.9831 - loss: 0.0667 - learning_rate: 2.5000e-05
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9902 - loss: 0.0897 - learning_rate: 2.5000e-05
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9455 - loss: 0.1240
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 72: val_accuracy did not improve from 0.87234
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 210ms/step - accuracy: 0.9458 - loss: 0.1236 - val_accuracy: 0.8298 - val_loss: 0.3058 - learning_rate: 2.5000e-05
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 219ms/step - accuracy: 0.9878 - loss: 0.0708 - learning_rate: 1.2500e-05
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 163ms/step - accuracy: 0.9748 - loss: 0.0926 - learning_rate: 1.2500e-05
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9707 - loss: 0.0898 - learning_rate: 1.2500e-05
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9731 - loss: 0.0821
# Epoch 76: val_accuracy did not improve from 0.87234
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9734 - loss: 0.0818 - val_accuracy: 0.8617 - val_loss: 0.3071 - learning_rate: 1.2500e-05
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 56.
# --- Evaluating Model ---
# 2/2 - 0s - 213ms/step - accuracy: 0.8571 - loss: 0.5811
#
# Accuracy: 0.8571
# Loss: 0.5811
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step

# %% [markdown]
# ### Model Development (Bi-LSTM using MFCC)

# %%
import json
import os
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Input, Bidirectional, LSTM
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Importing the JSON files
BASE_PATH = r"C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET"
TRAIN_JSON_PATH = os.path.join(BASE_PATH, "train_MFCC_CNN_dur3.json")
VALIDATION_JSON_PATH = os.path.join(BASE_PATH, "validation_MFCC_CNN_dur3.json")
TEST_JSON_PATH = os.path.join(BASE_PATH, "test_MFCC_CNN_dur3.json")

# Creating a dunction for loadind dataset
def load_data_from_file(data_path):

    print(f"Uploading data from: {data_path}")
    with open(data_path, "r") as fp:
        data = json.load(fp)

    mfcc_left = np.array(data["mfcc_left"])
    mfcc_right = np.array(data["mfcc_right"])
    y = np.array(data["labels"])
    
    mask = (y == 2) | (y == 3)
    
    X_unfiltered = np.stack((mfcc_left, mfcc_right), axis=-1)
    
    X_filtered = X_unfiltered[mask]
    y_filtered = y[mask]

    y_remapped = y_filtered.copy()
    y_remapped[y_filtered == 2] = 0
    y_remapped[y_filtered == 3] = 1

    X = X_filtered[..., np.newaxis]
    y = y_remapped

    print(f"  -> Shape X: {X.shape}, Shape Y: {y.shape}")
    print(f"  -> Label: {np.unique(y)}")
    return X, y

# Creating a plot for ploting accuracy and loss
def plot_history(history, validation_freq=1):
    
    import numpy as np

    train_acc  = np.array(history.history["accuracy"])
    train_loss = np.array(history.history["loss"])
    val_acc    = np.array(history.history.get("val_accuracy", []))
    val_loss   = np.array(history.history.get("val_loss", []))

    epochs = np.arange(1, len(train_acc) + 1)

    if validation_freq > 1 and len(val_acc) > 0:
        val_epochs = np.arange(validation_freq, len(train_acc) + 1, validation_freq)
        train_acc  = train_acc[val_epochs - 1]
        train_loss = train_loss[val_epochs - 1]
        epochs     = val_epochs

    fig, axs = plt.subplots(2, figsize=(10, 8))

    axs[0].plot(epochs, train_acc, label="Training Accuracy")
    if len(val_acc):
        axs[0].plot(epochs, val_acc, label="Validation Accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")

    axs[1].plot(epochs, train_loss, label="Training Loss")
    if len(val_loss):
        axs[1].plot(epochs, val_loss, label="Validation Loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")

    plt.tight_layout()
    plt.show()

# Creating a function for building model
def build_bidirectional_lstm_model(input_shape):

    model = Sequential()

    model.add(Bidirectional(LSTM(32, kernel_regularizer=keras.regularizers.l2(0.01)), input_shape=input_shape))
    model.add(Dropout(0.6))

    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.6))

    model.add(Dense(2, activation='softmax'))

    return model


if __name__ == "__main__":

    X_train_orig, y_train = load_data_from_file(TRAIN_JSON_PATH)
    X_validation_orig, y_validation = load_data_from_file(VALIDATION_JSON_PATH)
    X_test_orig, y_test = load_data_from_file(TEST_JSON_PATH)

    timesteps = X_train_orig.shape[1]
    num_features = X_train_orig.shape[2] * X_train_orig.shape[3]

    X_train = X_train_orig.reshape(-1, timesteps, num_features)
    X_validation = X_validation_orig.reshape(-1, timesteps, num_features)
    X_test = X_test_orig.reshape(-1, timesteps, num_features)
    
    print(f"\nShape of data after reshaping for LSTM purpose:")
    print(f"  -> X_train shape: {X_train.shape}")
    print(f"  -> X_validation shape: {X_validation.shape}")
    print(f"  -> X_test shape: {X_test.shape}\n")
    
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_bidirectional_lstm_model(input_shape)

    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
    
    # Tambahkan ini sebelum training
    checkpoint_path = "BiLSTM_MFCC_best_model.weights.h5"
    model_checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )
    
    # EarlyStopping berdasarkan akurasi validasi, bukan loss
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=5,  # berhenti jika val_accuracy stagnan/turun 5 kali berturut-turut
        restore_best_weights=True,
        mode='max',
        verbose=1
    )
    
    # Learning rate scheduler tetap
    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        mode='max',
        verbose=1
    )
    
    # Mulai training dengan validasi setiap 4 epoch
    history = model.fit(
        X_train, y_train,
        validation_data=(X_validation, y_validation),
        batch_size=8,
        epochs=100,
        callbacks=[early_stopping, model_checkpoint],
        verbose=1,
        validation_freq=4  # validasi setiap 4 epoch
    )

    model.load_weights(checkpoint_path)
    plot_history(history, validation_freq=4)

    print("\n--- Evaluating Model ---")
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print(f'\nAccuracy: {test_acc:.4f}')
    print(f'Loss: {test_loss:.4f}')

    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs[:, 1] > 0.5).astype(int) 
    
    # Calculating confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    labels = np.unique(y_test)
    
    # Visualizing the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()
# Out:
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\train_MFCC_CNN_dur3.json
#   -> Shape X: (220, 517, 32, 2, 1), Shape Y: (220,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\validation_MFCC_CNN_dur3.json
#   -> Shape X: (94, 517, 32, 2, 1), Shape Y: (94,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\test_MFCC_CNN_dur3.json
#   -> Shape X: (56, 517, 32, 2, 1), Shape Y: (56,)
#   -> Label: [0 1]
#
# Shape of data after reshaping for LSTM purpose:
#   -> X_train shape: (220, 517, 64)
#   -> X_validation shape: (94, 517, 64)
#   -> X_test shape: (56, 517, 64)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,978 (105.38 KB)
#  Trainable params: 26,978 (105.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.4651 - loss: 2.7212
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.4903 - loss: 2.5011
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 237ms/step - accuracy: 0.4764 - loss: 2.5373
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.5610 - loss: 2.3532
# Epoch 4: val_accuracy improved from -inf to 0.45745, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 283ms/step - accuracy: 0.5597 - loss: 2.3538 - val_accuracy: 0.4574 - val_loss: 2.2926
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 205ms/step - accuracy: 0.5835 - loss: 2.2929
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 186ms/step - accuracy: 0.6192 - loss: 2.2439
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 188ms/step - accuracy: 0.5707 - loss: 2.2575
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.5265 - loss: 2.2363
# Epoch 8: val_accuracy improved from 0.45745 to 0.60638, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.5263 - loss: 2.2363 - val_accuracy: 0.6064 - val_loss: 2.1826
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.4981 - loss: 2.2465
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 227ms/step - accuracy: 0.4661 - loss: 2.2475
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 239ms/step - accuracy: 0.5766 - loss: 2.1484
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.5436 - loss: 2.1567
# Epoch 12: val_accuracy improved from 0.60638 to 0.67021, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 262ms/step - accuracy: 0.5448 - loss: 2.1560 - val_accuracy: 0.6702 - val_loss: 2.0876
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.4974 - loss: 2.1516
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.5308 - loss: 2.1162
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 192ms/step - accuracy: 0.5393 - loss: 2.0197
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.4949 - loss: 2.0452
# Epoch 16: val_accuracy did not improve from 0.67021
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 244ms/step - accuracy: 0.4951 - loss: 2.0448 - val_accuracy: 0.6383 - val_loss: 1.9998
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.4798 - loss: 2.0190
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 214ms/step - accuracy: 0.5749 - loss: 1.9615
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 0.5082 - loss: 1.9948
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5406 - loss: 1.9414
# Epoch 20: val_accuracy did not improve from 0.67021
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 236ms/step - accuracy: 0.5411 - loss: 1.9409 - val_accuracy: 0.6383 - val_loss: 1.9178
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.5303 - loss: 1.9325
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 211ms/step - accuracy: 0.4813 - loss: 1.9092
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.4448 - loss: 1.9228
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.6332 - loss: 1.8317
# Epoch 24: val_accuracy improved from 0.67021 to 0.70213, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 242ms/step - accuracy: 0.6307 - loss: 1.8325 - val_accuracy: 0.7021 - val_loss: 1.8401
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 207ms/step - accuracy: 0.5315 - loss: 1.8807
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 215ms/step - accuracy: 0.5373 - loss: 1.8128
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 201ms/step - accuracy: 0.5247 - loss: 1.7939
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.6536 - loss: 1.7454
# Epoch 28: val_accuracy did not improve from 0.70213
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.6518 - loss: 1.7460 - val_accuracy: 0.6489 - val_loss: 1.7603
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 197ms/step - accuracy: 0.5788 - loss: 1.7725
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step - accuracy: 0.6989 - loss: 1.6845
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.6243 - loss: 1.7214
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.5881 - loss: 1.7032
# Epoch 32: val_accuracy improved from 0.70213 to 0.71277, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 8s 295ms/step - accuracy: 0.5889 - loss: 1.7027 - val_accuracy: 0.7128 - val_loss: 1.6832
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 6s 209ms/step - accuracy: 0.6132 - loss: 1.6671
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.5992 - loss: 1.6721
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.7251 - loss: 1.6107
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5953 - loss: 1.6249
# Epoch 36: val_accuracy did not improve from 0.71277
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 166ms/step - accuracy: 0.5950 - loss: 1.6248 - val_accuracy: 0.6809 - val_loss: 1.6160
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.6407 - loss: 1.6014
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.6810 - loss: 1.5809
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.7172 - loss: 1.5155
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.6544 - loss: 1.5254
# Epoch 40: val_accuracy improved from 0.71277 to 0.74468, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.6541 - loss: 1.5257 - val_accuracy: 0.7447 - val_loss: 1.5341
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6705 - loss: 1.5222
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.6358 - loss: 1.5718
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.6911 - loss: 1.5194
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.5903 - loss: 1.5289
# Epoch 44: val_accuracy improved from 0.74468 to 0.75532, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.5919 - loss: 1.5273 - val_accuracy: 0.7553 - val_loss: 1.4726
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6621 - loss: 1.4693
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.6761 - loss: 1.5403
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.6866 - loss: 1.4631
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6906 - loss: 1.4106
# Epoch 48: val_accuracy did not improve from 0.75532
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 135ms/step - accuracy: 0.6911 - loss: 1.4101 - val_accuracy: 0.7128 - val_loss: 1.4164
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.6628 - loss: 1.4441
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 100ms/step - accuracy: 0.7034 - loss: 1.3991
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 163ms/step - accuracy: 0.6622 - loss: 1.3698
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.7617 - loss: 1.3599
# Epoch 52: val_accuracy did not improve from 0.75532
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.7592 - loss: 1.3610 - val_accuracy: 0.7340 - val_loss: 1.3610
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7794 - loss: 1.3236
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.7628 - loss: 1.2968
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 132ms/step - accuracy: 0.7913 - loss: 1.2747
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.6920 - loss: 1.3289
# Epoch 56: val_accuracy improved from 0.75532 to 0.80851, saving model to BiLSTM_MFCC_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6934 - loss: 1.3281 - val_accuracy: 0.8085 - val_loss: 1.3040
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7650 - loss: 1.2801
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.7511 - loss: 1.3302
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.7823 - loss: 1.2503
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8024 - loss: 1.2027
# Epoch 60: val_accuracy did not improve from 0.80851
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.8020 - loss: 1.2028 - val_accuracy: 0.7553 - val_loss: 1.2717
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - accuracy: 0.7923 - loss: 1.2280
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.8065 - loss: 1.2049
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.7625 - loss: 1.2607
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8156 - loss: 1.1953
# Epoch 64: val_accuracy did not improve from 0.80851
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 161ms/step - accuracy: 0.8151 - loss: 1.1949 - val_accuracy: 0.7553 - val_loss: 1.2227
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8233 - loss: 1.1663
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7911 - loss: 1.1631
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.8152 - loss: 1.1736
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8263 - loss: 1.1175
# Epoch 68: val_accuracy did not improve from 0.80851
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8255 - loss: 1.1184 - val_accuracy: 0.7340 - val_loss: 1.2040
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8233 - loss: 1.0884
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.8529 - loss: 1.1359
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8721 - loss: 1.0476
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8602 - loss: 1.0774
# Epoch 72: val_accuracy did not improve from 0.80851
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8600 - loss: 1.0776 - val_accuracy: 0.7234 - val_loss: 1.1614
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - accuracy: 0.8110 - loss: 1.0858
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.8737 - loss: 1.0068
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.7925 - loss: 1.0948
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8440 - loss: 1.0289
# Epoch 76: val_accuracy did not improve from 0.80851
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 144ms/step - accuracy: 0.8441 - loss: 1.0286 - val_accuracy: 0.7979 - val_loss: 1.1146
# Epoch 76: early stopping
# Restoring model weights from the end of the best epoch: 56.
# --- Evaluating Model ---
# 2/2 - 0s - 57ms/step - accuracy: 0.6250 - loss: 1.3245
#
# Accuracy: 0.6250
# Loss: 1.3245
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step

# %% [markdown]
# # SVD-based Spectrogram using CNN & Bi-LSTM

# %% [markdown]
# ### Feature Extraction

# %%
import json
import os
import librosa
import numpy as np
from scipy.signal import butter, sosfilt
import sys

# Dataset path
BASE_DATASET_PATH = r"C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\MAN\ALL COMBINED V2"

# The extracted features are splitted into three JSON files: training, validation, testing
TRAIN_JSON_PATH = "train_SVD_CNN_mfcc32_dur3_sr22050.json"
VALIDATION_JSON_PATH = "validation_SVD_CNN_mfcc32_dur3_sr22050.json"
TEST_JSON_PATH = "test_SVD_CNN_mfcc32_dur3_sr22050.json"

# Defining Parameters
SAMPLE_RATE = 22050
TRACK_DURATION = 3  # in seconds
SAMPLES_PER_TRACK = int(SAMPLE_RATE * TRACK_DURATION)
NUM_MFCC = 32
N_FFT = 2048
HOP_LENGTH = 128
K = 32

# Creating a function for filtering 250-2000 Hz
def bandpass_filter(signal, sr, lowcut=250, highcut=2000, order=5):
    """Menerapkan filter bandpass ke sinyal."""
    sos = butter(order, [lowcut, highcut], btype='band', fs=sr, output='sos')
    return sosfilt(sos, signal)

# Creating a function for calculating SVD
def compute_s_dot_vt(spec, k):

    U, _, Vt = np.linalg.svd(spec, full_matrices=False)
    Vt_k = Vt[:k, :]  # shape: (k, T)
    return Vt_k  # shape: (k, T)

# Creating a function for extracting Spectrogram from datasets
def process_data(base_path, class_mappings, splits_to_process):

    all_data = {split: {"labels": [], "log_spec_left": [], "log_spec_right": []} for split in splits_to_process}

    for label_index, class_name in enumerate(class_mappings):
        print(f"\nProcessing Class: {class_name} (Label: {label_index})")
        
        for split_name in splits_to_process:
            split_path = os.path.join(base_path, class_name, split_name)
            
            if not os.path.isdir(split_path):
                print(f"  -> Directory is not found, pass: {split_path}")
                continue
            
            print(f"  -> Split Processing: {split_name}")

            for f in sorted(os.listdir(split_path)):
                if not f.lower().endswith(('.wav', '.mp3', '.flac')):
                    continue
                    
                file_path = os.path.join(split_path, f)
                
                try:
                    signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE, mono=False)

                    if signal.shape[0] != 2:
                        print(f"      -> Passing non-stereo file: {f}")
                        continue

                    # Adding paddings for datasets that are below 3 seconds
                    if signal.shape[1] < SAMPLES_PER_TRACK:
                        pad_length = SAMPLES_PER_TRACK - signal.shape[1]
                        signal = np.pad(signal, ((0, 0), (0, pad_length)), mode="constant")
                    elif signal.shape[1] > SAMPLES_PER_TRACK:
                        signal = signal[:, :SAMPLES_PER_TRACK]

                    left_channel = bandpass_filter(signal[0], sample_rate)
                    right_channel = bandpass_filter(signal[1], sample_rate)

                    # Compute power spectrogram
                    spec_left = np.abs(librosa.stft(left_channel, n_fft=N_FFT, hop_length=HOP_LENGTH)) ** 2
                    spec_right = np.abs(librosa.stft(right_channel, n_fft=N_FFT, hop_length=HOP_LENGTH)) ** 2
    
                    # Convert to log scale
                    log_spec_left = librosa.power_to_db(spec_left)
                    log_spec_right = librosa.power_to_db(spec_right)
                                                      
                    all_data[split_name]["log_spec_left"].append(log_spec_left)
                    all_data[split_name]["log_spec_right"].append(log_spec_right)
                    all_data[split_name]["labels"].append(label_index)

                except Exception as e:
                    print(f"      -> Failed to load file {f}. Error: {e}")

    return all_data

# Creating a fucntion for saving the JSON file
def save_to_json(data, json_path, class_mappings):
    data_to_save = {
        "mapping": class_mappings,
        "labels": data["labels"],
        "Vt_k_left": [arr.tolist() for arr in data["log_spec_left"]],
        "Vt_k_right": [arr.tolist() for arr in data["log_spec_right"]]
    }
    with open(json_path, "w") as fp:
        json.dump(data_to_save, fp, indent=4)
    print(f"\nData has been saved in {json_path}")

if __name__ == "__main__":
    try:
        class_mappings = sorted([d for d in os.listdir(BASE_DATASET_PATH) if os.path.isdir(os.path.join(BASE_DATASET_PATH, d))])
        if not class_mappings:
            raise FileNotFoundError
    except FileNotFoundError:
        print(f"❌ ERROR: No class folder found in: {BASE_DATASET_PATH}")
        print("Ensure the path contains folder 'High Intelligibility' dan 'Low Intelligibility'.")
        sys.exit()

    print(f"Class detected: {class_mappings}")

    splits = ["training", "validation", "testing"]
    processed_data = process_data(BASE_DATASET_PATH, class_mappings, splits)

    train_data = processed_data["training"]
    validation_data = processed_data["validation"]
    test_data = processed_data["testing"]

    # Calculating normalization..
    all_train_spec_left = np.vstack(train_data["log_spec_left"])
    all_train_spec_right = np.vstack(train_data["log_spec_right"])
    
    mean_left = np.mean(all_train_spec_left, axis=0)
    std_left = np.std(all_train_spec_left, axis=0)
    mean_right = np.mean(all_train_spec_right, axis=0)
    std_right = np.std(all_train_spec_right, axis=0)
    
    epsilon = 1e-10
    for split_name in splits:
        current_data = processed_data[split_name]
        current_data["log_spec_left"] = [(spec - mean_left) / (std_left + epsilon) for spec in current_data["log_spec_left"]]
        current_data["log_spec_right"] = [(spec - mean_right) / (std_right + epsilon) for spec in current_data["log_spec_right"]]
    
    print("\nNormalization for training dataset has been successfullt calculated.")

    print("\nApplying SVD to the datasets..")
    for split_name in splits:
        current_data = processed_data[split_name]
        current_data["log_spec_left"] = [compute_s_dot_vt(spec, K) for spec in current_data["log_spec_left"]]
        current_data["log_spec_right"] = [compute_s_dot_vt(spec, K) for spec in current_data["log_spec_right"]]
    print("SVD is succesfully applied.")

    # Saving the JSON file
    save_to_json(train_data, TRAIN_JSON_PATH, class_mappings)
    save_to_json(validation_data, VALIDATION_JSON_PATH, class_mappings)
    save_to_json(test_data, TEST_JSON_PATH, class_mappings)
    
    print("\n✅ Process is over.")

# %% [markdown]
# ### Model Development (CNN using SVD-based Spectrogram)

# %%
import json
import os
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Input, SpatialDropout3D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Importing the JSON files
BASE_PATH = r"C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET"
TRAIN_JSON_PATH = os.path.join(BASE_PATH, "train_SVD_CNN_dur3.json")
VALIDATION_JSON_PATH = os.path.join(BASE_PATH, "validation_SVD_CNN_dur3.json")
TEST_JSON_PATH = os.path.join(BASE_PATH, "test_SVD_CNN_dur3.json")

# Creating a dunction for loadind dataset
def load_data_from_file(data_path):
   
    print(f"Uploading data from: {data_path}")
    with open(data_path, "r") as fp:
        data = json.load(fp)

    Vt_k_left = np.array(data["Vt_k_left"])
    Vt_k_right = np.array(data["Vt_k_left"])
    y = np.array(data["labels"])
    
    mask = (y == 2) | (y == 3)
    
    X_unfiltered = np.stack((Vt_k_left, Vt_k_right), axis=-1)
    
    X_filtered = X_unfiltered[mask]
    y_filtered = y[mask]

    y_remapped = y_filtered.copy()
    y_remapped[y_filtered == 2] = 0
    y_remapped[y_filtered == 3] = 1

    X = X_filtered[..., np.newaxis]
    y = y_remapped

    print(f"  -> Shape X: {X.shape}, Shape Y: {y.shape}")
    print(f"  -> Label: {np.unique(y)}")
    return X, y

# Creating a plot for ploting accuracy and loss
def plot_history(history, validation_freq=1):
    
    import numpy as np

    train_acc  = np.array(history.history["accuracy"])
    train_loss = np.array(history.history["loss"])
    val_acc    = np.array(history.history.get("val_accuracy", []))
    val_loss   = np.array(history.history.get("val_loss", []))

    epochs = np.arange(1, len(train_acc) + 1)

    if validation_freq > 1 and len(val_acc) > 0:
        val_epochs = np.arange(validation_freq, len(train_acc) + 1, validation_freq)
        train_acc  = train_acc[val_epochs - 1]
        train_loss = train_loss[val_epochs - 1]
        epochs     = val_epochs

    fig, axs = plt.subplots(2, figsize=(10, 8))

    axs[0].plot(epochs, train_acc, label="Training Accuracy")
    if len(val_acc):
        axs[0].plot(epochs, val_acc, label="Validation Accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")

    axs[1].plot(epochs, train_loss, label="Training Loss")
    if len(val_loss):
        axs[1].plot(epochs, val_loss, label="Validation Loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")

    plt.tight_layout()
    plt.show()

# Creating a function for building model
def build_model(input_shape):

    model = Sequential()
    
    model.add(Conv3D(filters=16, kernel_size=(3, 5, 2), activation='relu', input_shape=input_shape, padding='same'))
    model.add(BatchNormalization())
    model.add(SpatialDropout3D(0.3))
    model.add(MaxPooling3D(pool_size=(3, 3, 2)))
    
    model.add(Conv3D(filters=32, kernel_size=(3, 5, 2), activation='relu', kernel_regularizer=keras.regularizers.l2(0.001), padding='same'))
    model.add(BatchNormalization())
    model.add(SpatialDropout3D(0.3))
    model.add(MaxPooling3D(pool_size=(3, 3, 1)))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(2, activation='softmax'))

    return model


if __name__ == "__main__":

    X_train, y_train = load_data_from_file(TRAIN_JSON_PATH)
    X_validation, y_validation = load_data_from_file(VALIDATION_JSON_PATH)
    X_test, y_test = load_data_from_file(TEST_JSON_PATH)

    input_shape = X_train.shape[1:]
    model = build_model(input_shape)

    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
    
    # Tambahkan ini sebelum training
    checkpoint_path = "CNN_SVD_best_model.weights.h5"
    model_checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )
    
    # EarlyStopping berdasarkan akurasi validasi, bukan loss
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=5,  # berhenti jika val_accuracy stagnan/turun 5 kali berturut-turut
        restore_best_weights=True,
        mode='max',
        verbose=1
    )
    
    # Learning rate scheduler tetap
    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        mode='max',
        verbose=1
    )
    
    # Mulai training dengan validasi setiap 4 epoch
    history = model.fit(
        X_train, y_train,
        validation_data=(X_validation, y_validation),
        batch_size=8,
        epochs=100,
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1,
        validation_freq=4  # validasi setiap 4 epoch
    )

    model.load_weights(checkpoint_path)
    plot_history(history, validation_freq=4)

    print("\n--- Evaluating Model ---")
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print(f'\nAccuracy: {test_acc:.4f}')
    print(f'Loss: {test_loss:.4f}')

    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs[:, 1] > 0.5).astype(int) 
    
    # Calculating confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    labels = np.unique(y_test)
    
    # Visualizing the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()
# Out:
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\train_SVD_CNN_dur3.json
#   -> Shape X: (220, 32, 517, 2, 1), Shape Y: (220,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\validation_SVD_CNN_dur3.json
#   -> Shape X: (94, 32, 517, 2, 1), Shape Y: (94,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\test_SVD_CNN_dur3.json
#   -> Shape X: (56, 32, 517, 2, 1), Shape Y: (56,)
#   -> Label: [0 1]
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d_1 (Conv3D)                    │ (None, 32, 517, 2, 16)      │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 517, 2, 16)      │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout3d (SpatialDropout3D) │ (None, 32, 517, 2, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d (MaxPooling3D)         │ (None, 10, 172, 1, 16)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_2 (Conv3D)                    │ (None, 10, 172, 1, 32)      │          15,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 10, 172, 1, 32)      │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ spatial_dropout3d_1                  │ (None, 10, 172, 1, 32)      │               0 │
# │ (SpatialDropout3D)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_1 (MaxPooling3D)       │ (None, 3, 57, 1, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 5472)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │         700,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 716,882 (2.73 MB)
#  Trainable params: 716,786 (2.73 MB)
#  Non-trainable params: 96 (384.00 B)
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 89ms/step - accuracy: 0.5293 - loss: 2.1043 - learning_rate: 1.0000e-04
# Epoch 2/100
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\model_checkpoint.py:302: UserWarning: Can save best model only with val_accuracy available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6207 - loss: 1.1841 - learning_rate: 1.0000e-04
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.6201 - loss: 0.9749 - learning_rate: 1.0000e-04
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.6886 - loss: 0.7525
# Epoch 4: val_accuracy improved from -inf to 0.51064, saving model to CNN_SVD_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 145ms/step - accuracy: 0.6875 - loss: 0.7552 - val_accuracy: 0.5106 - val_loss: 0.7331 - learning_rate: 1.0000e-04
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.6837 - loss: 0.6951 - learning_rate: 1.0000e-04
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - accuracy: 0.6477 - loss: 0.8404 - learning_rate: 1.0000e-04
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6272 - loss: 0.7520 - learning_rate: 1.0000e-04
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.6396 - loss: 0.7293
# Epoch 8: val_accuracy did not improve from 0.51064
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.6409 - loss: 0.7278 - val_accuracy: 0.5106 - val_loss: 1.1334 - learning_rate: 1.0000e-04
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.7047 - loss: 0.6296 - learning_rate: 1.0000e-04
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.7858 - loss: 0.4481 - learning_rate: 1.0000e-04
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7828 - loss: 0.4903 - learning_rate: 1.0000e-04
# Epoch 12/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7045 - loss: 0.5832
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 12: val_accuracy did not improve from 0.51064
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - accuracy: 0.7061 - loss: 0.5830 - val_accuracy: 0.5106 - val_loss: 0.8839 - learning_rate: 1.0000e-04
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7757 - loss: 0.4618 - learning_rate: 5.0000e-05
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7427 - loss: 0.4548 - learning_rate: 5.0000e-05
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7374 - loss: 0.5324 - learning_rate: 5.0000e-05
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7431 - loss: 0.4545
# Epoch 16: val_accuracy improved from 0.51064 to 0.59574, saving model to CNN_SVD_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.7449 - loss: 0.4533 - val_accuracy: 0.5957 - val_loss: 0.6527 - learning_rate: 5.0000e-05
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7383 - loss: 0.4878 - learning_rate: 5.0000e-05
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7841 - loss: 0.4606 - learning_rate: 5.0000e-05
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.8521 - loss: 0.3938 - learning_rate: 5.0000e-05
# Epoch 20/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7990 - loss: 0.4325
# Epoch 20: val_accuracy improved from 0.59574 to 0.65957, saving model to CNN_SVD_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.7981 - loss: 0.4323 - val_accuracy: 0.6596 - val_loss: 0.6166 - learning_rate: 5.0000e-05
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8863 - loss: 0.3476 - learning_rate: 5.0000e-05
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step - accuracy: 0.8073 - loss: 0.3648 - learning_rate: 5.0000e-05
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8001 - loss: 0.4388 - learning_rate: 5.0000e-05
# Epoch 24/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8022 - loss: 0.4476
# Epoch 24: val_accuracy improved from 0.65957 to 0.71277, saving model to CNN_SVD_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8036 - loss: 0.4459 - val_accuracy: 0.7128 - val_loss: 0.5946 - learning_rate: 5.0000e-05
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.8562 - loss: 0.3839 - learning_rate: 5.0000e-05
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8364 - loss: 0.3734 - learning_rate: 5.0000e-05
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8217 - loss: 0.4197 - learning_rate: 5.0000e-05
# Epoch 28/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8560 - loss: 0.3163
# Epoch 28: val_accuracy did not improve from 0.71277
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.8581 - loss: 0.3159 - val_accuracy: 0.7128 - val_loss: 0.6017 - learning_rate: 5.0000e-05
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.8714 - loss: 0.2876 - learning_rate: 5.0000e-05
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8466 - loss: 0.3562 - learning_rate: 5.0000e-05
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.8612 - loss: 0.3281 - learning_rate: 5.0000e-05
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8917 - loss: 0.2693
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 32: val_accuracy did not improve from 0.71277
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.8916 - loss: 0.2701 - val_accuracy: 0.6596 - val_loss: 0.6236 - learning_rate: 5.0000e-05
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9036 - loss: 0.2414 - learning_rate: 2.5000e-05
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8853 - loss: 0.2427 - learning_rate: 2.5000e-05
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.9177 - loss: 0.2315 - learning_rate: 2.5000e-05
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8786 - loss: 0.2395
# Epoch 36: val_accuracy did not improve from 0.71277
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8784 - loss: 0.2405 - val_accuracy: 0.7021 - val_loss: 0.6283 - learning_rate: 2.5000e-05
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.9098 - loss: 0.2592 - learning_rate: 2.5000e-05
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.8778 - loss: 0.2963 - learning_rate: 2.5000e-05
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 153ms/step - accuracy: 0.9468 - loss: 0.1828 - learning_rate: 2.5000e-05
# Epoch 40/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8845 - loss: 0.2378
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 40: val_accuracy did not improve from 0.71277
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.8875 - loss: 0.2360 - val_accuracy: 0.7128 - val_loss: 0.6310 - learning_rate: 2.5000e-05
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - accuracy: 0.9411 - loss: 0.2008 - learning_rate: 1.2500e-05
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9257 - loss: 0.2374 - learning_rate: 1.2500e-05
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8674 - loss: 0.2750 - learning_rate: 1.2500e-05
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9347 - loss: 0.2054
# Epoch 44: val_accuracy did not improve from 0.71277
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9343 - loss: 0.2057 - val_accuracy: 0.6915 - val_loss: 0.6455 - learning_rate: 1.2500e-05
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 24.
# --- Evaluating Model ---
# 2/2 - 0s - 115ms/step - accuracy: 0.7321 - loss: 0.6034
#
# Accuracy: 0.7321
# Loss: 0.6034
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step

# %% [markdown]
# ### Model Development (Bi-LSTM using SVD-based Spectrogram)

# %%
import json
import os
import numpy as np
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Importing the JSON files
BASE_PATH = r"C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET"
TRAIN_JSON_PATH = os.path.join(BASE_PATH, "train_SVD_CNN_dur3.json")
VALIDATION_JSON_PATH = os.path.join(BASE_PATH, "validation_SVD_CNN_dur3.json")
TEST_JSON_PATH = os.path.join(BASE_PATH, "test_SVD_CNN_dur3.json")

# Creating a dunction for loadind dataset
def load_data_from_file(data_path):

    print(f"Uploading data from: {data_path}")
    with open(data_path, "r") as fp:
        data = json.load(fp)

    Vt_k_left = np.array(data["Vt_k_left"])
    Vt_k_right = np.array(data["Vt_k_right"])
    y = np.array(data["labels"])
    
    mask = (y == 2) | (y == 3)
    
    X_unfiltered = np.stack((Vt_k_left, Vt_k_right), axis=-1)
    
    X_filtered = X_unfiltered[mask]
    y_filtered = y[mask]

    y_remapped = y_filtered.copy()
    y_remapped[y_filtered == 2] = 0
    y_remapped[y_filtered == 3] = 1

    X = X_filtered[..., np.newaxis]
    y = y_remapped

    print(f"  -> Shape X: {X.shape}, Shape Y: {y.shape}")
    print(f"  -> Label: {np.unique(y)}")
    return X, y

# Creating a plot for ploting accuracy and loss
def plot_history(history, validation_freq=1):
    
    import numpy as np

    train_acc  = np.array(history.history["accuracy"])
    train_loss = np.array(history.history["loss"])
    val_acc    = np.array(history.history.get("val_accuracy", []))
    val_loss   = np.array(history.history.get("val_loss", []))

    epochs = np.arange(1, len(train_acc) + 1)

    if validation_freq > 1 and len(val_acc) > 0:
        val_epochs = np.arange(validation_freq, len(train_acc) + 1, validation_freq)
        train_acc  = train_acc[val_epochs - 1]
        train_loss = train_loss[val_epochs - 1]
        epochs     = val_epochs

    fig, axs = plt.subplots(2, figsize=(10, 8))

    axs[0].plot(epochs, train_acc, label="Training Accuracy")
    if len(val_acc):
        axs[0].plot(epochs, val_acc, label="Validation Accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")

    axs[1].plot(epochs, train_loss, label="Training Loss")
    if len(val_loss):
        axs[1].plot(epochs, val_loss, label="Validation Loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")

    plt.tight_layout()
    plt.show()

# Creating a function for building model
def build_bidirectional_lstm_model(input_shape):

    model = Sequential()

    model.add(Bidirectional(LSTM(32, kernel_regularizer=keras.regularizers.l2(0.01)), input_shape=input_shape))
    model.add(Dropout(0.6))

    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.6))

    model.add(Dense(2, activation='softmax'))

    return model


if __name__ == "__main__":

    X_train_orig, y_train = load_data_from_file(TRAIN_JSON_PATH)
    X_validation_orig, y_validation = load_data_from_file(VALIDATION_JSON_PATH)
    X_test_orig, y_test = load_data_from_file(TEST_JSON_PATH)

    timesteps = X_train_orig.shape[1]
    num_features = X_train_orig.shape[2] * X_train_orig.shape[3]

    X_train = X_train_orig.reshape(-1, timesteps, num_features)
    X_validation = X_validation_orig.reshape(-1, timesteps, num_features)
    X_test = X_test_orig.reshape(-1, timesteps, num_features)
    
    print(f"\nShape of data after reshaping for LSTM purpose:")
    print(f"  -> X_train shape: {X_train.shape}")
    print(f"  -> X_validation shape: {X_validation.shape}")
    print(f"  -> X_test shape: {X_test.shape}\n")
    
    input_shape = (X_train.shape[1], X_train.shape[2])
    model = build_bidirectional_lstm_model(input_shape)

    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
    
    # Tambahkan ini sebelum training
    checkpoint_path = "BiLSTM_SVD_best_model.weights.h5"
    model_checkpoint = ModelCheckpoint(
        checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
        verbose=1
    )
    
    # EarlyStopping berdasarkan akurasi validasi, bukan loss
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=5,  # berhenti jika val_accuracy stagnan/turun 5 kali berturut-turut
        restore_best_weights=True,
        mode='max',
        verbose=1
    )
    
    # Learning rate scheduler tetap
    reduce_lr = ReduceLROnPlateau(
        monitor='val_accuracy',
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        mode='max',
        verbose=1
    )
    
    # Mulai training dengan validasi setiap 4 epoch
    history = model.fit(
        X_train, y_train,
        validation_data=(X_validation, y_validation),
        batch_size=8,
        epochs=100,
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1,
        validation_freq=4  # validasi setiap 4 epoch
    )

    model.load_weights(checkpoint_path)
    plot_history(history, validation_freq=4)

    print("\n--- Evaluating Model ---")
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print(f'\nAccuracy: {test_acc:.4f}')
    print(f'Loss: {test_loss:.4f}')

    y_pred_probs = model.predict(X_test)
    y_pred = (y_pred_probs[:, 1] > 0.5).astype(int) 
    
    # Calculating confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    labels = np.unique(y_test)
    
    # Visualizing the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap=plt.cm.Blues)
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()
# Out:
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\train_SVD_CNN_dur3.json
#   -> Shape X: (220, 32, 517, 2, 1), Shape Y: (220,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\validation_SVD_CNN_dur3.json
#   -> Shape X: (94, 32, 517, 2, 1), Shape Y: (94,)
#   -> Label: [0 1]
# Uploading data from: C:\Users\ndaru\OneDrive - KFUPM\THESIS\DATASET\test_SVD_CNN_dur3.json
#   -> Shape X: (56, 32, 517, 2, 1), Shape Y: (56,)
#   -> Label: [0 1]
#
# Shape of data after reshaping for LSTM purpose:
#   -> X_train shape: (220, 32, 1034)
#   -> X_validation shape: (94, 32, 1034)
#   -> X_test shape: (56, 32, 1034)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_7 (Bidirectional)      │ (None, 64)                  │         273,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_44 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_30 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_45 (Dense)                     │ (None, 2)                   │              66 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 275,298 (1.05 MB)
#  Trainable params: 275,298 (1.05 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.4441 - loss: 5.1338 - learning_rate: 1.0000e-04
# Epoch 2/100
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\early_stopping.py:153: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss
#   current = self.get_monitor_value(logs)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\callback_list.py:145: UserWarning: Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: accuracy,loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# C:\Users\ndaru\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\callbacks\model_checkpoint.py:302: UserWarning: Can save best model only with val_accuracy available.
#   if self._should_save_model(epoch, batch, logs, filepath):
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.6233 - loss: 4.6740 - learning_rate: 1.0000e-04
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5394 - loss: 4.2797 - learning_rate: 1.0000e-04
# Epoch 4/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5791 - loss: 3.9201
# Epoch 4: val_accuracy improved from -inf to 0.68085, saving model to BiLSTM_SVD_best_model.weights.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 124ms/step - accuracy: 0.5799 - loss: 3.9147 - val_accuracy: 0.6809 - val_loss: 3.6631 - learning_rate: 1.0000e-04
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.5721 - loss: 3.5918 - learning_rate: 1.0000e-04
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6479 - loss: 3.2920 - learning_rate: 1.0000e-04
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5970 - loss: 3.0219 - learning_rate: 1.0000e-04
# Epoch 8/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.6826 - loss: 2.7823
# Epoch 8: val_accuracy did not improve from 0.68085
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.6785 - loss: 2.7789 - val_accuracy: 0.6702 - val_loss: 2.6150 - learning_rate: 1.0000e-04
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.6062 - loss: 2.5661 - learning_rate: 1.0000e-04
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6952 - loss: 2.3620 - learning_rate: 1.0000e-04
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.6336 - loss: 2.1937 - learning_rate: 1.0000e-04
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6547 - loss: 2.0309
# Epoch 12: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 12: val_accuracy did not improve from 0.68085
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.6538 - loss: 2.0298 - val_accuracy: 0.6809 - val_loss: 1.9279 - learning_rate: 1.0000e-04
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6195 - loss: 1.9041 - learning_rate: 5.0000e-05
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.6342 - loss: 1.8502 - learning_rate: 5.0000e-05
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6827 - loss: 1.7790 - learning_rate: 5.0000e-05
# Epoch 16/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6029 - loss: 1.7329
# Epoch 16: val_accuracy did not improve from 0.68085
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.6055 - loss: 1.7310 - val_accuracy: 0.6809 - val_loss: 1.6776 - learning_rate: 5.0000e-05
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.6219 - loss: 1.6694 - learning_rate: 5.0000e-05
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6128 - loss: 1.6159 - learning_rate: 5.0000e-05
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7239 - loss: 1.5447 - learning_rate: 5.0000e-05
# Epoch 20/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6131 - loss: 1.5210
# Epoch 20: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 20: val_accuracy did not improve from 0.68085
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6160 - loss: 1.5194 - val_accuracy: 0.6809 - val_loss: 1.4727 - learning_rate: 5.0000e-05
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.7198 - loss: 1.4530 - learning_rate: 2.5000e-05
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.6084 - loss: 1.4441 - learning_rate: 2.5000e-05
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.6716 - loss: 1.3970 - learning_rate: 2.5000e-05
# Epoch 24/100
# 27/28 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6334 - loss: 1.4026
# Epoch 24: val_accuracy did not improve from 0.68085
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6345 - loss: 1.4015 - val_accuracy: 0.6809 - val_loss: 1.3850 - learning_rate: 2.5000e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 4.
# --- Evaluating Model ---
# 2/2 - 0s - 60ms/step - accuracy: 0.6786 - loss: 1.4089
#
# Accuracy: 0.6786
# Loss: 1.4089
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
